# %%
import tweepy
import networkx as nx
import pandas as pd
from time import sleep
import datetime

# %%
df = pd.read_csv('tweetLDA20192021.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1          name    screen_name      id_str location  \
# 0           0             0  Alternativet  alternativet_  1704527995      NaN
# 1           1             1  Alternativet  alternativet_  1704527995      NaN
#
#                                          description  followers_count  \
# 0  Alternativet er for mennesker, der ønsker en s...          30210.0
# 1  Alternativet er for mennesker, der ønsker en s...          30210.0
#
#    friends_count  statuses_count  ...     tweet_created_at  is_retweet  \
# 0         3816.0         29702.0  ...  2021-06-03 07:19:50        True
# 1         3816.0         29702.0  ...  2021-06-03 06:37:54       False
#
#                                            tweet_txt  \
# 0  Vi skal give familierne omsorg, så de får over...
# 1  Den grønne Å-fane var stærkt til stede i går v...
#
#                                           mentions  \
# 0  ['Mira81743596', 'alternativet_', 'informeren']
# 1                                               []
#
#                       hashtags retweet_user  \
# 0  ['bæredygtigtliv', 'dkpol']      NHOERUP
# 1             ['klimalovbrud']          NaN
#
#                                            text_proc  \
# 0  ['vi', 'skal', 'give', 'familierne', 'omsorg',...
# 1  ['den', 'grønne', 'å-fane', 'var', 'stærkt', '...
#
#                            text_stemmed_no_stopwords  \
# 0  giv famili omsorg så får overskud giv natur om...
# 1  grøn å-fan stærk sted går ved #klimalovbrud de...
#
#                                             unigrams  \
# 0  ['giv', 'famili', 'omsorg', 'så', 'får', 'over...
# 1  ['grøn', 'å-fan', 'stærk', 'sted', 'går', 'ved...
#
#                                              bigrams
# 0  ['giv_famili', 'famili_omsorg', 'omsorg_så', '...
# 1  ['grøn_å-fan', 'å-fan_stærk', 'stærk_sted', 's...
#
# [2 rows x 22 columns]

# %%
df=df.drop(['Unnamed: 0.1'], axis=1)

# %%
df=df.drop(['Unnamed: 0'], axis=1)

# %%
df = df.drop(['location'], axis=1)

# %%
df.head(1)
# Out:
#            name    screen_name      id_str  \
# 0  Alternativet  alternativet_  1704527995
#
#                                          description  followers_count  \
# 0  Alternativet er for mennesker, der ønsker en s...          30210.0
#
#    friends_count  statuses_count                 user_created_at  \
# 0         3816.0         29702.0  Tue Aug 27 11:53:50 +0000 2013
#
#        tweet_id     tweet_created_at  is_retweet  \
# 0  1.400352e+18  2021-06-03 07:19:50        True
#
#                                            tweet_txt  \
# 0  Vi skal give familierne omsorg, så de får over...
#
#                                           mentions  \
# 0  ['Mira81743596', 'alternativet_', 'informeren']
#
#                       hashtags retweet_user  \
# 0  ['bæredygtigtliv', 'dkpol']      NHOERUP
#
#                                            text_proc  \
# 0  ['vi', 'skal', 'give', 'familierne', 'omsorg',...
#
#                            text_stemmed_no_stopwords  \
# 0  giv famili omsorg så får overskud giv natur om...
#
#                                             unigrams  \
# 0  ['giv', 'famili', 'omsorg', 'så', 'får', 'over...
#
#                                              bigrams
# 0  ['giv_famili', 'famili_omsorg', 'omsorg_så', '...

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 5000)

# %%
df.tail(1000)
# Out:
#                                   name      screen_name               id_str  \
# 21846               Konservativ Ungdom            KU_DK            522083654
# 21847               Konservativ Ungdom            KU_DK            522083654
# 21848               Konservativ Ungdom            KU_DK            522083654
# 21849               Konservativ Ungdom            KU_DK            522083654
# 21850               Konservativ Ungdom            KU_DK            522083654
# 21851               Konservativ Ungdom            KU_DK            522083654
# 21852               Konservativ Ungdom            KU_DK            522083654
# 21853               Konservativ Ungdom            KU_DK            522083654
# 21854               Konservativ Ungdom            KU_DK            522083654
# 21855               Konservativ Ungdom            KU_DK            522083654
# 21856               Konservativ Ungdom            KU_DK            522083654
# 21857               Konservativ Ungdom            KU_DK            522083654
# 21858               Konservativ Ungdom            KU_DK            522083654
# 21859               Konservativ Ungdom            KU_DK            522083654
# 21860               Konservativ Ungdom            KU_DK            522083654
# 21861         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21862         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21863         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21864         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21865         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21866         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21867         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21868         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21869         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21870         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21871         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21872         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21873         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21874         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21875         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21876         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21877         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21878         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21879         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21880         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21881         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21882         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21883         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21884         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21885         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21886         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21887         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21888         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21889         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21890         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21891         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21892         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21893         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21894         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21895         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21896         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21897         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21898         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21899         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21900         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21901         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21902         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21903         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21904         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21905         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21906         Liberal Alliances Ungdom  LiberalUngdomDK           2605831046
# 21907                   Radikal Ungdom    radikalungdom             24722242
# 21908                   Radikal Ungdom    radikalungdom             24722242
# 21909                   Radikal Ungdom    radikalungdom             24722242
# 21910                   Radikal Ungdom    radikalungdom             24722242
# 21911                   Radikal Ungdom    radikalungdom             24722242
# 21912                   Radikal Ungdom    radikalungdom             24722242
# 21913                   Radikal Ungdom    radikalungdom             24722242
# 21914                   Radikal Ungdom    radikalungdom             24722242
# 21915                   Radikal Ungdom    radikalungdom             24722242
# 21916                   Radikal Ungdom    radikalungdom             24722242
# 21917                   Radikal Ungdom    radikalungdom             24722242
# 21918                   Radikal Ungdom    radikalungdom             24722242
# 21919                   Radikal Ungdom    radikalungdom             24722242
# 21920                   Radikal Ungdom    radikalungdom             24722242
# 21921                   Radikal Ungdom    radikalungdom             24722242
# 21922                   Radikal Ungdom    radikalungdom             24722242
# 21923                   Radikal Ungdom    radikalungdom             24722242
# 21924                   Radikal Ungdom    radikalungdom             24722242
# 21925                   Radikal Ungdom    radikalungdom             24722242
# 21926                   Radikal Ungdom    radikalungdom             24722242
# 21927                   Radikal Ungdom    radikalungdom             24722242
# 21928                   Radikal Ungdom    radikalungdom             24722242
# 21929                   Radikal Ungdom    radikalungdom             24722242
# 21930                   Radikal Ungdom    radikalungdom             24722242
# 21931                   Radikal Ungdom    radikalungdom             24722242
# 21932                   Radikal Ungdom    radikalungdom             24722242
# 21933                   Radikal Ungdom    radikalungdom             24722242
# 21934                   Radikal Ungdom    radikalungdom             24722242
# 21935                   Radikal Ungdom    radikalungdom             24722242
# 21936                   Radikal Ungdom    radikalungdom             24722242
# 21937                   Radikal Ungdom    radikalungdom             24722242
# 21938                   Radikal Ungdom    radikalungdom             24722242
# 21939                   Radikal Ungdom    radikalungdom             24722242
# 21940                   Radikal Ungdom    radikalungdom             24722242
# 21941                   Radikal Ungdom    radikalungdom             24722242
# 21942                   Radikal Ungdom    radikalungdom             24722242
# 21943                   Radikal Ungdom    radikalungdom             24722242
# 22281                        SF Ungdom        SF_Ungdom           1615444519
# 22282                        SF Ungdom        SF_Ungdom           1615444519
# 22283                        SF Ungdom        SF_Ungdom           1615444519
# 22284                        SF Ungdom        SF_Ungdom           1615444519
# 22285                        SF Ungdom        SF_Ungdom           1615444519
# 22286                        SF Ungdom        SF_Ungdom           1615444519
# 22287                              DSU         DSU_1920           1201451732
# 22288                              DSU         DSU_1920           1201451732
# 22289                              DSU         DSU_1920           1201451732
# 22290                              DSU         DSU_1920           1201451732
# 22291                              DSU         DSU_1920           1201451732
# 22292                              DSU         DSU_1920           1201451732
# 22293                              DSU         DSU_1920           1201451732
# 22294                              DSU         DSU_1920           1201451732
# 22295                              DSU         DSU_1920           1201451732
# 22296                              DSU         DSU_1920           1201451732
# 22297                              DSU         DSU_1920           1201451732
# 22298                              DSU         DSU_1920           1201451732
# 22299                              DSU         DSU_1920           1201451732
# 22300                              DSU         DSU_1920           1201451732
# 22301                              DSU         DSU_1920           1201451732
# 22302                              DSU         DSU_1920           1201451732
# 22303                              DSU         DSU_1920           1201451732
# 22304                              DSU         DSU_1920           1201451732
# 22305                              DSU         DSU_1920           1201451732
# 22306                              DSU         DSU_1920           1201451732
# 22307                              DSU         DSU_1920           1201451732
# 22308                              DSU         DSU_1920           1201451732
# 22309                              DSU         DSU_1920           1201451732
# 22310                              DSU         DSU_1920           1201451732
# 22311                              DSU         DSU_1920           1201451732
# 22312                              DSU         DSU_1920           1201451732
# 22313                              DSU         DSU_1920           1201451732
# 22314                              DSU         DSU_1920           1201451732
# 22315                              DSU         DSU_1920           1201451732
# 22316                              DSU         DSU_1920           1201451732
# 22317                              DSU         DSU_1920           1201451732
# 22318                              DSU         DSU_1920           1201451732
# 22319                              DSU         DSU_1920           1201451732
# 22320                              DSU         DSU_1920           1201451732
# 22321                              DSU         DSU_1920           1201451732
# 22322                              DSU         DSU_1920           1201451732
# 22323                              DSU         DSU_1920           1201451732
# 22324                              DSU         DSU_1920           1201451732
# 22325                              DSU         DSU_1920           1201451732
# 22326                              DSU         DSU_1920           1201451732
# 22327                              DSU         DSU_1920           1201451732
# 22328                              DSU         DSU_1920           1201451732
# 22329                              DSU         DSU_1920           1201451732
# 22330                              DSU         DSU_1920           1201451732
# 22331                              DSU         DSU_1920           1201451732
# 22332                              DSU         DSU_1920           1201451732
# 22333                              DSU         DSU_1920           1201451732
# 22334                              DSU         DSU_1920           1201451732
# 22335                              DSU         DSU_1920           1201451732
# 22336                              DSU         DSU_1920           1201451732
# 22337                              DSU         DSU_1920           1201451732
# 22338                              DSU         DSU_1920           1201451732
# 22339                              DSU         DSU_1920           1201451732
# 22340                              DSU         DSU_1920           1201451732
# 22341                              DSU         DSU_1920           1201451732
# 22342                              DSU         DSU_1920           1201451732
# 22343                              DSU         DSU_1920           1201451732
# 22344                              DSU         DSU_1920           1201451732
# 22345                              DSU         DSU_1920           1201451732
# 22346                              DSU         DSU_1920           1201451732
# 22347                              DSU         DSU_1920           1201451732
# 22348                              DSU         DSU_1920           1201451732
# 22349                              DSU         DSU_1920           1201451732
# 22350                              DSU         DSU_1920           1201451732
# 22351                              DSU         DSU_1920           1201451732
# 22352                              DSU         DSU_1920           1201451732
# 22353                              DSU         DSU_1920           1201451732
# 22354                              DSU         DSU_1920           1201451732
# 22355                              DSU         DSU_1920           1201451732
# 22356                              DSU         DSU_1920           1201451732
# 22357                              DSU         DSU_1920           1201451732
# 22358                              DSU         DSU_1920           1201451732
# 22359                              DSU         DSU_1920           1201451732
# 22360                              DSU         DSU_1920           1201451732
# 22361                              DSU         DSU_1920           1201451732
# 22362                              DSU         DSU_1920           1201451732
# 22363                              DSU         DSU_1920           1201451732
# 22364                              DSU         DSU_1920           1201451732
# 22365                              DSU         DSU_1920           1201451732
# 22366                              DSU         DSU_1920           1201451732
# 22367                              DSU         DSU_1920           1201451732
# 22368                              DSU         DSU_1920           1201451732
# 22369                              DSU         DSU_1920           1201451732
# 22370                              DSU         DSU_1920           1201451732
# 22371                              DSU         DSU_1920           1201451732
# 22372                              DSU         DSU_1920           1201451732
# 22373                              DSU         DSU_1920           1201451732
# 22374                              DSU         DSU_1920           1201451732
# 22375                              DSU         DSU_1920           1201451732
# 22376                              DSU         DSU_1920           1201451732
# 22377                              DSU         DSU_1920           1201451732
# 22378                              DSU         DSU_1920           1201451732
# 22379                              DSU         DSU_1920           1201451732
# 22380                              DSU         DSU_1920           1201451732
# 22381                              DSU         DSU_1920           1201451732
# 22382                              DSU         DSU_1920           1201451732
# 22383                              DSU         DSU_1920           1201451732
# 22384                              DSU         DSU_1920           1201451732
# 22385                              DSU         DSU_1920           1201451732
# 22386                              DSU         DSU_1920           1201451732
# 22387                              DSU         DSU_1920           1201451732
# 22388                              DSU         DSU_1920           1201451732
# 22389                              DSU         DSU_1920           1201451732
# 22390                              DSU         DSU_1920           1201451732
# 22391                              DSU         DSU_1920           1201451732
# 22392                              DSU         DSU_1920           1201451732
# 22393                              DSU         DSU_1920           1201451732
# 22394                              DSU         DSU_1920           1201451732
# 22395                              DSU         DSU_1920           1201451732
# 22396                              DSU         DSU_1920           1201451732
# 22397                              DSU         DSU_1920           1201451732
# 22398                              DSU         DSU_1920           1201451732
# 22399                              DSU         DSU_1920           1201451732
# 22400                              DSU         DSU_1920           1201451732
# 22401                              DSU         DSU_1920           1201451732
# 22402                              DSU         DSU_1920           1201451732
# 22403                              DSU         DSU_1920           1201451732
# 22404                              DSU         DSU_1920           1201451732
# 22405                              DSU         DSU_1920           1201451732
# 22406                              DSU         DSU_1920           1201451732
# 22407                              DSU         DSU_1920           1201451732
# 22408                              DSU         DSU_1920           1201451732
# 22409                              DSU         DSU_1920           1201451732
# 22410                              DSU         DSU_1920           1201451732
# 22411                              DSU         DSU_1920           1201451732
# 22412                              DSU         DSU_1920           1201451732
# 22413                              DSU         DSU_1920           1201451732
# 22414                              DSU         DSU_1920           1201451732
# 22415                              DSU         DSU_1920           1201451732
# 22416                              DSU         DSU_1920           1201451732
# 22417                              DSU         DSU_1920           1201451732
# 22418                              DSU         DSU_1920           1201451732
# 22419                              DSU         DSU_1920           1201451732
# 22420                              DSU         DSU_1920           1201451732
# 22421                              DSU         DSU_1920           1201451732
# 22422                              DSU         DSU_1920           1201451732
# 22423                              DSU         DSU_1920           1201451732
# 22424                              DSU         DSU_1920           1201451732
# 22425                              DSU         DSU_1920           1201451732
# 22426                              DSU         DSU_1920           1201451732
# 22427                              DSU         DSU_1920           1201451732
# 22428                              DSU         DSU_1920           1201451732
# 22429                              DSU         DSU_1920           1201451732
# 22430                              DSU         DSU_1920           1201451732
# 22431                              DSU         DSU_1920           1201451732
# 22432                              DSU         DSU_1920           1201451732
# 22433                              DSU         DSU_1920           1201451732
# 22434                              DSU         DSU_1920           1201451732
# 22435                              DSU         DSU_1920           1201451732
# 22436                              DSU         DSU_1920           1201451732
# 22437                              DSU         DSU_1920           1201451732
# 22438                              DSU         DSU_1920           1201451732
# 22439                              DSU         DSU_1920           1201451732
# 22440                              DSU         DSU_1920           1201451732
# 22441                              DSU         DSU_1920           1201451732
# 22442                              DSU         DSU_1920           1201451732
# 22443                              DSU         DSU_1920           1201451732
# 22444                              DSU         DSU_1920           1201451732
# ...
# 22575  ['dsu_oglt', 'oglt_kær', 'kær_spolitik', 'spol...
# 22576  ['aktivt_sagt', 'sagt_ja', 'ja_ent', 'ent_mund...
# 22577  ['allanschmid_espdanmark', 'espdanmark_justits...
# 22578  ['prm_brug', 'brug_samtykkelov', 'samtykkelov_...
# 22579  ['overskrift_#samtykkelovnu', '#samtykkelovnu_...
# 22580  ['reception_dansk', 'dansk_gymnasieelev', 'gym...
# 22581  ['igen_år', 'år_mul', 'mul_se', 'se_dsu-fodbol...
# 22582  ['barrikad_hongkong', 'hongkong_vis', 'vis_stå...
# 22583  ['glæd_tal', 'tal_demonstration', 'demonstrati...
# 22584  ['morg_kl', 'kl_demonstration', 'demonstration...
# 22585  ['nielsgmelk_politik', 'politik_ckrzyrosiak', ...
# 22586  ['tre_tidl', 'tidl_dsuer', 'dsuer_kom', 'kom_h...
# 22587  ['sgu_hver', 'hver_dag', 'dag_får', 'får_overr...
# 22588  ['kulturminist_joymogens', 'joymogens_overræk'...
# 22589  ['besøg_klima', 'klima_-', '-_energi', 'energi...
# 22590  ['adgccki_mariannevind', 'mariannevind_nej', '...
# 22591  ['ep-medlem_mariannevind', 'mariannevind_gæst'...
# 22592  ['husk_hold', 'hold_hånd', 'hånd_vor', 'vor_in...
# 22593  ['virk_stor', 'stor_opbakning', 'opbakning_stø...
# 22594  ['debat_artikel', 'artikel_raesondk', 'raesond...
# 22595  ['stor_sorg', 'sorg_kun', 'kun_læs', 'læs_tidl...
# 22596  ['ung_vælg', 'vælg_høj', 'høj_grad', 'grad_udd...
# 22597  ['status_besøg', 'besøg_jobpatrulj', 'jobpatru...
# 22598  ['nin_year', 'year_passed', 'passed_but', 'but...
# 22599  ['ni_år', 'år_sid', 'sid_ung', 'ung_socialdemo...
# 22600  ['én_man', 'man_kan', 'kan_vis', 'vis_så', 'så...
# 22601  ['dag_stop', 'stop_mind', 'mind_ildsjæl', 'ild...
# 22602  ['driv_virksom', 'virksom_ansæt', 'ansæt_ung',...
# 22603  ['lad_kald', 'kald_spad', 'spad_spad', 'spad_f...
# 22604  ['dsu_ønsk', 'ønsk_stort', 'stort_tillyk', 'ti...
# 22605  ['spani_går', 'går_rigt', 'rigt_vej', 'vej_kam...
# 22606  ['år_gået', 'gået_sid', 'sid_folkedrab', 'folk...
# 22607  ['juli_måned', 'måned_dsuer', 'dsuer_#jobpatru...
# 22608  ['cocktail_drikkekort', 'drikkekort_fjern', 'f...
# 22609  ['godt_nok', 'nok_vild', 'vild_find', 'find_re...
# 22610  ['nye_landstræn', 'landstræn_kasp', 'kasp_hjul...
# 22611  ['dsu_don', 'don_lidt', 'lidt_kr', 'kr_dansk',...
# 22612  ['år_sid', 'sid_dsu-regering', 'dsu-regering_p...
# 22613  ['brev_politik', 'politik_corona', 'corona_ung...
# 22614  ['aft_bjbrandenborg', 'bjbrandenborg_fornøj', ...
# 22615  ['bund_opgav', 'opgav_regering', 'regering_–',...
# 22616  ['forstem_hjert', 'hjert_europa', 'europa_stad...
# 22617  ['dsu_sig', 'sig_tak', 'tak_indsats', 'indsats...
# 22618  ['lad_sørg', 'sørg_coronakris', 'coronakris_ød...
# 22619  ['natalhariri_ombestem', 'ombestem_dsus', 'dsu...
# 22620  ['tak_klog', 'klog_tank', 'tank_fokus', 'fokus...
# 22621  ['derfor_foreslår', 'foreslår_dsu', 'dsu_lav',...
# 22622  ['to_artikl', 'artikl_sam', 'sam_dag', 'dag_ka...
# 22623  ['centralt_dsus', 'dsus_ungepak', 'ungepak_ung...
# 22624  ['dansk_bank', 'bank_slår', 'slår_igen', 'igen...
# 22625  ['tusindvis_lønmodtag', 'lønmodtag_blev', 'ble...
# 22626  ['vigt_brug', 'brug_skattesystem', 'skattesyst...
# 22627  ['åbenbart_nødt', 'nødt_slet', 'slet_tilhørsfo...
# 22628  ['sid_mur', 'mur_fald', 'fald_demokrati', 'dem...
# 22629  ['kujonag_ungarn', 'ungarn_glæd', 'glæd_tag', ...
# 22630  ['så_nyt', 'nyt_studenterkørsel', 'studenterkø...
# 22631  ['tid_kontak', 'kontak_dsu', 'dsu_uddan', 'udd...
# 22632  ['borger_giv', 'giv_skjult', 'skjult_skattelet...
# 22633  ['voksn_gik', 'gik_forhandlingslokal', 'forhan...
# 22634  ['trepartsaftal_fem', 'fem_mia', 'mia_kr', 'kr...
# 22635  ['godt_lønkompensation', 'lønkompensation_proc...
# 22636  ['ly_#coviddk', '#coviddk_fortsæt', 'fortsæt_o...
# 22637  ['stort_tillyk', 'tillyk_carlemillind', 'carle...
# 22638  ['dsu_dybt', 'dybt_bekymr', 'bekymr_udvikling'...
# 22639  ['dsu_tskriverjens', 'tskriverjens_jyllandspos...
# 22640  ['læs_fæl', 'fæl_debatindlæg', 'debatindlæg_jy...
# 22641  ['uforstå_virksom', 'virksom_gør', 'gør_brug',...
# 22642  ['brug_regering', 'regering_stempl', 'stempl_d...
# 22643  ['danmark_socialdemokratisk', 'socialdemokrati...
# 22644  ['nødt_sæt', 'sæt_tempo', 'tempo_grøn', 'grøn_...
# 22645  ['forbrug_betal', 'betal_indfør', 'indfør_co-a...
# 22646  ['netop_uddan', 'uddan_opkvalificering', 'opkv...
# 22647  ['udnyt_kris', 'kris_sæt', 'sæt_turbo', 'turbo...
# 22648  ['risik_tab', 'tab_hel', 'hel_generation', 'ge...
# 22649  ['se_fler', 'fler_ung', 'ung_mennesk', 'mennes...
# 22650  ['dag_fremlæg', 'fremlæg_dsu', 'dsu_ungeløft',...
# 22651  ['coronakris_godt', 'godt_gang', 'gang_træk', ...
# 22652  ['dag_international', 'international_dag', 'da...
# 22653  ['lad_find', 'find_hvordan', 'hvordan_etabl', ...
# 22654  ['stat_økonomi', 'økonomi_styr', 'styr_hushold...
# 22655  ['opråb_dsu', 'dsu_red', 'red_uddannelsesaftal...
# 22656  ['må_aldr', 'aldr_tag', 'tag_frihed', 'frihed_...
# 22657  ['mattiastesfay_adida', 'adida_hvert', 'hvert_...
# 22658  ['udlænd_-', '-_integrationsminist', 'integrat...
# 22659  ['står_evig', 'evig_gæld', 'gæld_dsu', 'dsu_gi...
# 22660  ['kurs_klar', 'klar_ung', 'ung_arbejd', 'arbej...
# 22661  ['coronakris_kan', 'kan_få', 'få_stor', 'stor_...
# 22662  ['ser_passivt', 'passivt_men', 'men_nation', '...
# 22663  ['troelsbeha_larshni', 'larshni_danskebankdk',...
# 22664  ['chefbonus_fortsæt', 'fortsæt_dbs', 'dbs_real...
# 22665  ['brug_nye', 'nye_socialdemokratisk', 'sociald...
# 22666  ['så_klar', 'klar_#tourdeskrald', '#tourdeskra...
# 22667  ['end_mangled', 'mangled_bar', 'bar_tid', 'tid...
# 22668  ['tro_skær', 'skær_velfærd', 'velfærd_øge', 'ø...
# 22669  ['chanc_vis', 'vis_politik', 'politik_betyd', ...
# 22670  ['spolitik_ét', 'ét_skud', 'skud_bøs', 'bøs_ka...
# 22671  ['dsus_forbundsformand', 'forbundsformand_fred...
# 22672  ['tak_dsu', 'dsu_sæt', 'sæt_fokus', 'fokus_for...
# 22673  ['prm_danmark', 'danmark_eu', 'eu_bør', 'bør_f...
# 22674  ['polsk_regering', 'regering_forbyd', 'forbyd_...
# 22675  ['tusindvis_mennesk', 'mennesk_mist', 'mist_ar...
# 22676  ['dsu_imod', 'imod_dispensation', 'dispensatio...
# 22677  ['histori_vist', 'vist_frivil', 'frivil_aftal'...
# 22678  ['eskroenhed_udstrak', 'udstrak_hånd', 'hånd_f...
# 22679  ['dsu_nej', 'nej_tak-ordning', 'tak-ordning_æn...
# 22680  ['gennemgang_dansk', 'dansk_pensionskas', 'pen...
# 22681  ['så_vor', 'vor_landsmød', 'landsmød_skudt', '...
# 22682  ['står_midt', 'midt_klima', 'klima_-', '-_natu...
# 22683  ['hold_lig', 'lig_så', 'så_kø', 'kø_elbil', 'e...
# 22684  ['dag_folketing', 'folketing_behandl', 'behand...
# 22685  ['nye_statsborgerskabsaftal', 'statsborgerskab...
# 22686  ['indfør_grøn', 'grøn_lær', 'lær_-', '-_prakti...
# 22687  ['person_bidrag', 'bidrag_vor', 'vor_valgkamps...
# 22688  ['dag_rgungdom', 'rgungdom_forsøg', 'forsøg_sa...
# 22689  ['tak_bidrag', 'bidrag_vor', 'vor_græsrodsvalg...
# 22690  ['bed_peng', 'peng_dag', 'dag_rgungdom', 'rgun...
# 22691  ['støt_lokal', 'lokal_socialist', 'socialist_\...
# 22692  ['hjælp_mal', 'mal_kommun', 'kommun_region', '...
# 22693  ['dag_valg', 'valg_byråd', 'byråd_regionsråd',...
# 22694  ['morg_får', 'får_rgungdom', 'rgungdom_afdelin...
# 22695  ['hold_landsmød', 'landsmød_knap', 'knap_tredj...
# 22696  ['socialistisk_feministisk', 'feministisk_møde...
# 22697  ['antal_selvmord', 'selvmord_selvmordsforsøg',...
# 22698  ['enig_så', 'så_gør', 'gør_ligesom', 'ligesom_...
# 22699  ['kan_kald', 'kald_børn', 'børn_statsminist', ...
# 22700  ['-_år', 'år_gammel', 'gammel_sønderjyd', 'søn...
# 22701  ['voks_voks', 'voks_🌿', '🌿_fået', 'fået_lokala...
# 22702  ['weekend_hold', 'hold_landsmød', 'landsmød_kl...
# 22703  ['rgungdom_allerførst', 'allerførst_landsmødeo...
# 22704  ['del_historisk', 'historisk_først', 'først_la...
# 22705  ['pak_vor', 'vor_digital', 'digital_landsmød',...
# 22706  ['klimakris_boligmangel', 'boligmangel_voks', ...
# 22707  ['start_dag', 'dag_gæstetal', 'gæstetal_dengro...
# 22708  ['ny_dag', 'dag_#rgulm', '#rgulm_nyt', 'nyt_ho...
# 22709  ['dag_dirigent', 'dirigent_vor', 'vor_digital'...
# 22710  ['politisk_ordfør', 'ordfør_maivillads', 'maiv...
# 22711  ['lang_god', 'god_debat', 'debat_klimaforandri...
# 22712  ['vindmøl_rejst', 'rejst_ved', 'ved_står', 'st...
# 22713  ['dag_sid', 'sid_rgungdom', 'rgungdom_s', 's_f...
# 22714  ['midt_kris', 'kris_dansk', 'dansk_mist', 'mis...
# 22715  ['shila_rgungdom', 'rgungdom_skrev', 'skrev_in...
# 22716  ['wolt_udnyt', 'udnyt_bud', 'bud_oft', 'oft_mi...
# 22717  ['vor_kandidat', 'kandidat_københavn', 'københ...
# 22718  ['kort_tid', 'tid_før', 'før_corona', 'corona_...
# 22719  ['sgu_hurt', 'hurt_vor', 'vor_nye', 'nye_polit...
# 22720  ['lig_børn', 'børn_statsminist', 'statsminist_...
# 22721  ['velkom_maivillads', 'maivillads_spids', 'spi...
# 22722  ['hej_liberalallianc', 'liberalallianc_syn', '...
# 22723  ['syn_maivillads', 'maivillads_fing', 'fing_pu...
# 22724  ['start_kæmp', 'kæmp_klima-brøl', 'klima-brøl_...
# 22725  ['mathild_jam', 'jam_rgungdom', 'rgungdom_sig'...
# 22726                ['tak_mathild', 'mathild_rgungdom']
# 22727  ['men_joe', 'joe_bid', 'bid_appel', 'appel_sam...
# 22728  ['end_trump-tid', 'trump-tid_ovr', 'ovr_bid', ...
# 22729  ['urafstemning_hus', 'hus_enhedslist', 'enheds...
# 22730  ['tak_opbakning', 'opbakning_plad', 'plad_enhe...
# 22731  ['flertal_enhedslist', 'enhedslist_københavn',...
# 22732  ['ældr_patient', 'patient_bryd', 'bryd_græd', ...
# 22733  ['coronakris_vist', 'vist_afgør', 'afgør_psyki...
# 22734  ['normering_dagsinstitution', 'dagsinstitution...
# 22735  ['lillem_vigtigtskrid', 'vigtigtskrid_palæstin...
# 22736  ['ærligtvi_træt', 'træt_ord', 'ord_hashtag', '...
# 22737  ['enhv_stilti', 'stilti_udenrigsminist', 'uden...
# 22738  ['godt_gået', 'gået_underskrift', 'underskrift...
# 22739  ['enhedslist_grøn', 'grøn_skattereform', 'skat...
# 22740  ['rød-grøn_ungdom', 'ungdom_drøm', 'drøm_fremt...
# 22741  ['jacobgissel_danskungdom', 'danskungdom_ungdk...
# 22742  ['dag_blev', 'blev_officielt', 'officielt_enhe...
# 22743  ['nedrevn_hjem', 'hjem_tvangsflytning', 'tvang...
# 22744  ['dag_god', 'god_dag', 'dag_ung', 'ung_venstre...
# 22745  ['duf_delegeretmød', 'delegeretmød_netop', 'ne...
# 22746  ['enhedslist_hovedbestyr', 'hovedbestyr_netop'...
# 22747  ['drøm_rødt', 'rødt_grønt', 'grønt_københavn',...
# 22748  ['enhedslist_norsk', 'norsk_søsterparti', 'søs...
# 22749  ['enhedslist_står', 'står_sam', 'sam_palæstine...
# 22750  ['detailbranch_så', 'så_stor', 'stor_indflyd',...
# 22751  ['emili_rød-grøn', 'rød-grøn_ungdom', 'ungdom_...
# 22752  ['novemb_vigt', 'vigt_dag', 'dag_mark', 'mark_...
# 22753  ['hold_👀', '👀_udov', 'udov_sej', 'sej_sygeplej...
# 22754  ['læng_råbt', 'råbt_behov', 'behov_styr', 'sty...
# 22755  ['regering_ude', 'ude_grønt', 'grønt_skråplan'...
# 22756  ['kreativ_måd', 'måd_sig', 'sig_drop', 'drop_k...
# 22757  ['stinelinneman_pelledragsted', 'pelledragsted...
# 22758  ['radikal_gør', 'gør_nemt', 'nemt_regering', '...
# 22759  ['minkavl_forbyd', 'forbyd_dk', 'dk_minkavl', ...
# 22760  ['stolt_uge', 'uge_stift', 'stift_lokalafdelin...
# 22761  ['kær_danjoergens', 'danjoergens_grib', 'grib_...
# 22762  ['olieindustri_vis', 'vis_mer', 'mer_handlekra...
# 22763  ['lig_netop', 'netop_derfor', 'derfor_klimalov...
# 22764  ['kom_godnatsang', 'godnatsang_børn', 'børn_mo...
# 22765  ['sker_lidt', 'lidt_sker', 'sker_langsomt', 'l...
# 22766  ['suc_enhedslist', 'enhedslist_valg', 'valg_år...
# 22767  ['vor_opfordring', 'opfordring_klar', 'klar_en...
# 22768                                       ['velkom_🥳']
# 22769  ['kort_før', 'før_midnat', 'midnat_runded', 'r...
# 22770  ['mart_saml', 'saml_ung', 'ung_socialist', 'so...
# 22771  ['opfordr_regering', 'regering_end', 'end_afsl...
# 22772  ['går_opstilled', 'opstilled_samarbejd', 'sama...
# 22773  ['mennesk_risik', 'risik_vold', 'vold_forfølg'...
# 22774  ['✊_🏽', '🏽_tag', 'tag_imod', 'imod_flygtning',...
# 22775  ['utro_spolitik', 'spolitik_tøv', 'tøv_co-afgi...
# 22776  ['🎉_igangdanmark', 'igangdanmark_fået', 'fået_...
# 22777  ['eid_mubarak', 'mubarak_vungdom', 'vungdom_fe...
# 22778  ['the_th', 'th_general', 'general_assembly', '...
# 22779  ['fornuft_vand', 'vand_frygt', 'frygt_dystr', ...
# 22780  ['godt_kapitalistisk', 'kapitalistisk_samfund'...
# 22781  ['lad_kom', 'kom_gang', 'gang_genåbn', 'genåbn...
# 22782  ['senest_år', 'år_blev', 'blev_tyd', 'tyd_brug...
# 22783  ['år_sid', 'sid_hel', 'hel_danmark', 'danmark_...
# 22784  ['fortal_ser', 'ser_nuanc', 'nuanc_kom', 'kom_...
# 22785  ['v-regering_spared', 'spared_årl', 'årl_uddan...
# 22786  ['kær_kudk', 'kudk_💚', '💚_må', 'må_godt', 'god...
# 22787  ['vungdom_eb', 'eb_annonc', 'annonc_hent', 'he...
# 22788  ['aft_tog', 'tog_først', 'først_lil', 'lil_skr...
# 22789  ['tak_mortendahlin', 'mortendahlin_klar', 'kla...
# 22790  ['lad_bar', 'bar_marked', 'marked_forbrug', 'f...
# 22791  ['vor_formand', 'formand_jakobelleman', 'jakob...
# 22792  ['kinakritik_samt', 'samt_dansk', 'dansk_ungdo...
# 22793  ['danmark_ungdomsparti', 'ungdomsparti_højr', ...
# 22794  ['glæd_kampdag', 'kampdag_kvind', 'kvind_aft',...
# 22795  ['tid_landsformand', 'landsformand_vungdom', '...
# 22796  ['franciskarosenk_ninnahedeag', 'ninnahedeag_f...
# 22797  ['facto_aflivning', 'aflivning_natteliv', 'nat...
# 22798  ['lad_fornuft', 'fornuft_råd', 'råd_genåbn', '...
# 22799  ['dsu_spolitik', 'spolitik_tordn', 'tordn_frem...
# 22800  ['børn_ofr', 'ofr_ideologisk', 'ideologisk_kor...
# 22801  ['andr_måd', 'måd_hånd', 'hånd_coronavirus', '...
# 22802  ['venstr_bør', 'bør_stem', 'stem_nej', 'nej_ny...
# 22803  ['dag_foreslår', 'foreslår_venstredk', 'venstr...
# 22804  ['vungdom_sæt', 'sæt_kom', 'kom_tid', 'tid_fok...
# 22805  ['senest_dag', 'dag_følg', 'følg_hvordan', 'hv...
# 22806  ['vungdom_enig', 'enig_venstr', 'venstr_dansk'...
# 22807  ['danmark_brug', 'brug_#liberalgenstart', '#li...
# 22808  ['to_gaml', 'gaml_vuer', 'vuer_støjberg', 'stø...
# 22809  ['spolitik_venstredk', 'venstredk_derfor', 'de...
# 22810  ['vu_enig', 'enig_rv', 'rv_bred', 'bred_co-afg...
# 22811  ['tid_opp', 'opp_medvirk', 'medvirk_-', '-_mor...
# 22812  ['så_endimensionelt', 'endimensionelt_syn', 's...
# 22813  ['venstr_ungdom', 'ungdom_fik', 'fik_morg', 'm...
# 22814  ['simon_emil', 'emil_ammitzbøll-bil', 'ammitzb...
# 22815  ['ved_ft-valg', 'ft-valg_gik', 'gik_stem', 'st...
# 22816  ['trist_se', 'se_split', 'split_flugt', 'flugt...
# 22817  ['vungdom_støt', 'støt_frit', 'frit_kurdistanv...
# 22818  ['landsstyrelsesmød_vu', 'vu_m', 'm_politisk',...
# 22819  ['in_our', 'our_latest', 'latest_articl', 'art...
# 22820  ['masseovervågning_nej', 'nej_tak', 'tak_#dkpo...
# 22821  ['kan_forstå', 'forstå_mettefrederik', 'mettef...
# 22822  ['hallowe_met', 'met_leen', 'leen_👻', '👻_isted...
# 22823  ['pskipperel_betrag', 'betrag_grundlæg', 'grun...
# 22824  ['tilstå_socialist', 'socialist_indrøm', 'indr...
# 22825  ['åbningstal_fik', 'fik_talt', 'talt_rig', 'ri...
# 22826  ['giv_lik', 'lik_vor', 'vor_nye', 'nye_formand...
# 22827  ['theyellowpet_sorenulka', 'sorenulka_alkohol'...
# 22828  ['venstr_ungdom', 'ungdom_drop', 'drop_tank', ...
# 22829  ['venstredk_land', 'land_størst', 'størst_part...
# 22830  ['færd_formand', 'formand_vungdom', 'vungdom_g...
# 22831  ['tusind_tak', 'tak_valg', 'valg_jer', 'jer_ny...
# 22832  ['rigt_godt', 'godt_landsstævn', 'landsstævn_v...
# 22833  ['mød_amira', 'amira_ambitiøs', 'ambitiøs_tag'...
# 22834  ['⚠_tour', 'tour_fedtspilleri', 'fedtspilleri_...
# 22835  ['friskol_kun', 'kun_rig', 'rig_børn', 'børn_d...
# 22836  ['massivt_velfærdsløft', 'velfærdsløft_uden', ...
# 22837  ['først_tim', 'tim_valg', 'valg_tvivl', 'tvivl...
# 22838  ['vungdom_klar', 'klar_kæmp', 'kæmp_fir', 'fir...
# 22839  ['bedrag_seri', 'seri_svindel', 'svindel_fup',...
# 22840  ['fordi_#kvinderneskampdag', '#kvinderneskampd...
# 22841  ['kæmp_afskaf', 'afskaf_topskat', 'topskat_💰',...
# 22842  ['kæmp_kort', 'kort_skoledag', 'skoledag_🏫', '...
# 22843  ['venstr_ungdom', 'ungdom_idag', 'idag_vedtag'...
# 22844  ['skud_sej', 'sej_hårdtarbejd', 'hårdtarbejd_m...
# 22845  ['astridkrag_lyt', 'lyt_lidt', 'lidt_astridkra...

# %%
len(df)
# Out:
# 22846

# %%
#Removing tweets that no longer contain meaning after preprocessing
df2 = df[pd.notnull(df['text_stemmed_no_stopwords'])]

# %%
len(df2)
# Out:
# 22799

# %%
new_df = df2.drop(['name'], axis=1)

# %%
new_df = new_df.drop(['description'], axis=1)
new_df = new_df.drop(['followers_count'], axis=1)
new_df = new_df.drop(['friends_count'], axis=1)
new_df = new_df.drop(['statuses_count'], axis=1)
new_df = new_df.drop(['user_created_at'], axis=1)
new_df = new_df.drop(['tweet_id'], axis=1)
new_df = new_df.drop(['tweet_created_at'], axis=1)
#new_df = new_df.drop(['mentions'], axis=1)
new_df = new_df.drop(['hashtags'], axis=1)
new_df = new_df.drop(['text_proc'], axis=1)
new_df = new_df.drop(['text_stemmed_no_stopwords'], axis=1)
new_df = new_df.drop(['unigrams'], axis=1)
new_df = new_df.drop(['bigrams'], axis=1)
new_df = new_df.drop(['id_str'], axis=1)

# %%
new_df
# Out:
#          screen_name  is_retweet  \
# 0      alternativet_        True
# 1      alternativet_       False
# 2      alternativet_       False
# 3      alternativet_       False
# 4      alternativet_       False
# ...              ...         ...
# 22841        VUngdom       False
# 22842        VUngdom       False
# 22843        VUngdom        True
# 22844        VUngdom        True
# 22845        VUngdom        True
#
#                                                tweet_txt  \
# 0      Vi skal give familierne omsorg, så de får over...
# 1      Den grønne Å-fane var stærkt til stede i går v...
# 2      På lørdag kl. 16.40 kan du høre vores politisk...
# 3      "Grøn brandtale af @TorstenGejl  slår benene v...
# 4                              💪 https://t.co/HHvxFi2CUK
# ...                                                  ...
# 22841  VI KÆMPER FOR AT AFSKAFFE TOPSKATTEN! 💰\n\nIng...
# 22842  VI KÆMPER FOR KORTERE SKOLEDAGE! 🏫\n\nLivet er...
# 22843  Venstres Ungdom har idag vedtaget på vores lan...
# 22844  Skud ud til de seje og hårdtarbejdende medlemm...
# 22845  .@Astridkrag i 2019 skulle lytte lidt til @Ast...
#
#                                                 mentions retweet_user
# 0        ['Mira81743596', 'alternativet_', 'informeren']      NHOERUP
# 1                                                     []          NaN
# 2                                    ['FranciskaRosenk']          NaN
# 3                                        ['TorstenGejl']          NaN
# 4                                                     []          NaN
# ...                                                  ...          ...
# 22841                                                 []          NaN
# 22842                                                 []          NaN
# 22843                                      ['venstredk']  MariaLagoni
# 22844                                        ['VUngdom']  JakobSabroe
# 22845  ['Astridkrag', 'Astridkrag', 'Spolitik', 'laeg...  JakobSabroe
#
# [22799 rows x 5 columns]

# %%
new_df.head()
# Out:
#      screen_name  is_retweet  \
# 0  alternativet_        True
# 1  alternativet_       False
# 2  alternativet_       False
# 3  alternativet_       False
# 4  alternativet_       False
#
#                                            tweet_txt  \
# 0  Vi skal give familierne omsorg, så de får over...
# 1  Den grønne Å-fane var stærkt til stede i går v...
# 2  På lørdag kl. 16.40 kan du høre vores politisk...
# 3  "Grøn brandtale af @TorstenGejl  slår benene v...
# 4                          💪 https://t.co/HHvxFi2CUK
#
#                                           mentions retweet_user
# 0  ['Mira81743596', 'alternativet_', 'informeren']      NHOERUP
# 1                                               []          NaN
# 2                              ['FranciskaRosenk']          NaN
# 3                                  ['TorstenGejl']          NaN
# 4                                               []          NaN

# %%
rt_df = new_df[new_df['is_retweet'] == True]

# %%
rt_df.head()
# Out:
#       screen_name  is_retweet  \
# 0   alternativet_        True
# 5   alternativet_        True
# 7   alternativet_        True
# 8   alternativet_        True
# 11  alternativet_        True
#
#                                             tweet_txt  \
# 0   Vi skal give familierne omsorg, så de får over...
# 5   I dag er det afslutningen på Folketingsåret og...
# 7   Alternativet har spurgt alle støttepartier og ...
# 8   “Vi vil ha, en grøn retfærdig fremtid!💚” https...
# 11  Et rigt og tilgængeligt kulturliv er på mange ...
#
#                                            mentions     retweet_user
# 0   ['Mira81743596', 'alternativet_', 'informeren']          NHOERUP
# 5                                                []    alternativet_
# 7                                                []      TorstenGejl
# 8                                                []  FranciskaRosenk
# 11                                               []  FranciskaRosenk

# %%
len(rt_df)
# Out:
# 15917

# %%
klima_rt = rt_df[rt_df.apply(lambda row: row.astype(str).str.contains
                                  ('klima'or 'grøn' or'miljø' or '#dkgreen' or 'bæredygtig' or 'CO2' or 'green' or 'natur').tweet_txt, axis=1)]

# %%
len(klima_rt)
# Out:
# 1532

# %%
klima_rt.head(2)
# Out:
#       screen_name  is_retweet  \
# 7   alternativet_        True
# 16  alternativet_        True
#
#                                             tweet_txt            mentions  \
# 7   Alternativet har spurgt alle støttepartier og ...                  []
# 16  Her til afslutningsdebatten mener statsministe...  ['DenGroenneStud']
#
#    retweet_user
# 7   TorstenGejl
# 16  TorstenGejl

# %%
#no. of parties retweeting about climate
print(len(klima_rt.screen_name.unique()))

#no. of actors being retweeted about climate
print(len(klima_rt.retweet_user.unique()))
# Out:
# 17
# 311

# %%
rt_nx_agg = klima_rt.groupby(["screen_name", "retweet_user"]).size().reset_index(name='simple_count')

#adding a count where we weigh the retweets of the same actor
rt_nx_agg["count"] = rt_nx_agg["simple_count"]**0.6

print(rt_nx_agg.head(40))
print(rt_nx_agg.shape)
# Out:
#         screen_name     retweet_user  simple_count      count
# 0   AlternativeUnge   AllonHSorensen             1   1.000000
# 1   AlternativeUnge    AndreasMulvad             1   1.000000
# 2   AlternativeUnge        AnnaBylov             1   1.000000
# 3   AlternativeUnge      AugustLund0             1   1.000000
# 4   AlternativeUnge        BEsbensen             1   1.000000
# 5   AlternativeUnge    BjarkeCharlie             1   1.000000
# 6   AlternativeUnge    ChristianPoll             1   1.000000
# 7   AlternativeUnge      CoHedegaard             1   1.000000
# 8   AlternativeUnge   Daniel_Hauberg             3   1.933182
# 9   AlternativeUnge       DavidTrads             1   1.000000
# 10  AlternativeUnge   DenGroenneStud             3   1.933182
# 11  AlternativeUnge       Emil_Ipsen             2   1.515717
# 12  AlternativeUnge   FrederikSandby             1   1.000000
# 13  AlternativeUnge         Grantzau             1   1.000000
# 14  AlternativeUnge       JM_Clausen             1   1.000000
# 15  AlternativeUnge  JesperTheilgard             1   1.000000
# 16  AlternativeUnge       Jesper_Pet             1   1.000000
# 17  AlternativeUnge        JiriTrnka             1   1.000000
# 18  AlternativeUnge  JohanHedegaardJ             1   1.000000
# 19  AlternativeUnge   JohnNordboCARE             1   1.000000
# 20  AlternativeUnge      JonBurgwald             1   1.000000
# 21  AlternativeUnge    JonathanRies_             2   1.515717
# 22  AlternativeUnge         Klimabev             1   1.000000
# 23  AlternativeUnge   KristianMadsen             1   1.000000
# 24  AlternativeUnge  Louiselorentze1             1   1.000000
# 25  AlternativeUnge       MadsMogwai             1   1.000000
# 26  AlternativeUnge       MathiasHK_             1   1.000000
# 27  AlternativeUnge       MhbLarsson             2   1.515717
# 28  AlternativeUnge          NOAH_dk             1   1.000000
# 29  AlternativeUnge        NaturThor             1   1.000000
# 30  AlternativeUnge      NillyTaheri             1   1.000000
# 31  AlternativeUnge     OliverWulffJ             7   3.214096
# 32  AlternativeUnge     Oscarschackm             4   2.297397
# 33  AlternativeUnge   RasmusKjeldahl             1   1.000000
# 34  AlternativeUnge      SofieGroth1             1   1.000000
# 35  AlternativeUnge        SorenHave             5   2.626528
# 36  AlternativeUnge       TScavenius             3   1.933182
# 37  AlternativeUnge      TorstenGejl             2   1.515717
# 38  AlternativeUnge      aggerhomien             1   1.000000
# 39  AlternativeUnge    alternativet_            47  10.075317
# (401, 4)

# %%
print(rt_nx_agg.tail(40))
# Out:
#     screen_name     retweet_user  simple_count     count
# 361    rgungdom          Maltesp             1  1.000000
# 362    rgungdom       PSkipperEL             1  1.000000
# 363    rgungdom   frederikdahler             3  1.933182
# 364      sufnet     MaiVilladsen             1  1.000000
# 365   venstredk       Altingetdk             1  1.000000
# 366   venstredk      AnneStergaa             1  1.000000
# 367   venstredk         AsgeriEU             1  1.000000
# 368   venstredk    DanmarksNatur             1  1.000000
# 369   venstredk      DanskEnergi             1  1.000000
# 370   venstredk      DebattenDR2             1  1.000000
# 371   venstredk          GSaabye             1  1.000000
# 372   venstredk    JakobEllemann             3  1.933182
# 373   venstredk   JanEJoergensen             2  1.515717
# 374   venstredk    KentDamsgaard             1  1.000000
# 375   venstredk  KristianLMadsen             2  1.515717
# 376   venstredk  Kristian_Jensen             6  2.930156
# 377   venstredk        L_Aagaard             2  1.515717
# 378   venstredk        LarsKunov             1  1.000000
# 379   venstredk     LarsSandahlS             3  1.933182
# 380   venstredk      LineaLidell             8  3.482202
# 381   venstredk  Loekkegaard_MEP             2  1.515717
# 382   venstredk     LouiseElholm             1  1.000000
# 383   venstredk    MariaGjerding             1  1.000000
# 384   venstredk     MortenDahlin             1  1.000000
# 385   venstredk      ThDanielsen             4  2.297397
# 386   venstredk          aahlers             8  3.482202
# 387   venstredk       brittbager             2  1.515717
# 388   venstredk   larsclilleholt             6  2.930156
# 389   venstredk       larsloekke             3  1.933182
# 390   venstredk         lpsoebye             1  1.000000
# 391   venstredk     marie_bjerre             3  1.933182
# 392   venstredk        politikdr             1  1.000000
# 393   venstredk         raesondk             1  1.000000
# 394   venstredk     sophieloehde             7  3.214096
# 395   venstredk    spisekammeret             1  1.000000
# 396   venstredk   stephanie_lose             1  1.000000
# 397   venstredk      troelslundp             2  1.515717
# 398   venstredk      troelsranis             1  1.000000
# 399   venstredk       tv2politik             2  1.515717
# 400   venstredk       ulrichbang             1  1.000000

# %%
for a in rt_nx_agg.screen_name.unique():
    G.add_node(a, typ='party')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cf0b11716280> in <module>
# ----> 1 for a in rt_nx_agg.screen_name.unique():
#       2     G.add_node(a, typ='party')
#
# NameError: name 'rt_nx_agg' is not defined

# %%
#creating our edge_list of sender and reciever and adding an edge attribute
G = nx.from_pandas_edgelist(rt_nx_agg,'screen_name','retweet_user',
                            edge_attr="count",
                            create_using = nx.DiGraph())
# Print the number of nodes and edges
print('Nodes in RT network:', len(G.nodes()))
print('Edges in RT network:', len(G.edges()))
# Out:
# Nodes in RT network: 321
# Edges in RT network: 401

# %%
nx.write_gexf(G, 'retweet_climate_subset.gexf')

# %%
from pyvis import network as net

# %%
pyvis_graph = net.Network(notebook=True,
                     height = "700px",
                     width = "700px",
                     bgcolor = "#f6f2e9")

# set the physics layout of the network
pyvis_graph.force_atlas_2based()

# Add Networkx data
pyvis_graph.from_nx(G)

# Save and show
pyvis_graph.show('climate_retweet_network.html')
# Out:
#         <iframe
#             width="700px"
#             height="700px"
#             src="climate_retweet_network.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Create size list
sizes = [x[1] for x in G.degree()]

# Draw the network
nx.draw_networkx(G, 
    with_labels = False, 
    node_size = sizes,
    width = 0.1, alpha = 0.7,
    arrowsize = 2, linewidths = 0)

# Turn axis off and show
plt.axis('off'); plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     395         try:
# --> 396             random_state_arg = args[random_state_index]
#     397         except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-121-5e9a34e73c08> in <module>
#       3
#       4 # Draw the network
# ----> 5 nx.draw_networkx(G,
#       6     with_labels = False,
#       7     node_size = sizes,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     331
#     332     if pos is None:
# --> 333         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     334
#     335     draw_networkx_nodes(G, pos, **node_kwds)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     398             raise nx.NetworkXError("random_state_index must be an integer") from e
#     399         except IndexError as e:
# --> 400             raise nx.NetworkXError("random_state_index is incorrect") from e
#     401
#     402         # Create a numpy.random.RandomState instance
#
# NetworkXError: random_state_index is incorrect

# %% [markdown]
# ## Mention network

# %%
klima_mention = klima_rt.copy()
klimamention = klima_mention.drop(['retweet_user'], axis = 1)
klimamention.head()
# Out:
#       screen_name  is_retweet  \
# 7   alternativet_        True
# 16  alternativet_        True
# 18  alternativet_        True
# 46  alternativet_        True
# 50  alternativet_        True
#
#                                             tweet_txt  \
# 7   Alternativet har spurgt alle støttepartier og ...
# 16  Her til afslutningsdebatten mener statsministe...
# 18  Tak til Mette Frederiksen for en fin tale til ...
# 46  .@informeren har spurgt partierne ift klimabor...
# 50  Lørdag deltog jeg i @klimamarchen. \n\nDet er ...
#
#                                            mentions
# 7                                                []
# 16                               ['DenGroenneStud']
# 18                                               []
# 46               ['informeren', 'dkgreen', 'dkpol']
# 50  ['klimamarchen', 'alternativet_', 'Naturmodet']

# %%
mentions = klimamention['mentions']

# %%
import re

# %%
mentions = mentions.astype(str)

# %%
type(mentions)
# Out:
# pandas.core.series.Series

# %%
mentions = mentions.apply(lambda x: re.sub ('\W', '', x))
#mentions = mentions.apply(lambda x: re.sub (']', '', x))
mentions
# Out:
# 7        None
# 16       None
# 18       None
# 46       None
# 50       None
#          ...
# 22758    None
# 22763    None
# 22765    None
# 22766    None
# 22770    None
# Name: mentions, Length: 1532, dtype: object

# %%
klimamention
# Out:
#          screen_name  is_retweet  \
# 7      alternativet_        True
# 16     alternativet_        True
# 18     alternativet_        True
# 46     alternativet_        True
# 50     alternativet_        True
# ...              ...         ...
# 22758       rgungdom        True
# 22763       rgungdom        True
# 22765       rgungdom        True
# 22766       rgungdom        True
# 22770       rgungdom        True
#
#                                                tweet_txt  \
# 7      Alternativet har spurgt alle støttepartier og ...
# 16     Her til afslutningsdebatten mener statsministe...
# 18     Tak til Mette Frederiksen for en fin tale til ...
# 46     .@informeren har spurgt partierne ift klimabor...
# 50     Lørdag deltog jeg i @klimamarchen. \n\nDet er ...
# ...                                                  ...
# 22758  Radikale gør det for nemt for regeringen at sl...
# 22763  "Der var lige netop, derfor vi skulle have en ...
# 22765  Der sker for lidt, og det sker for langsomt. V...
# 22766  Succes! Enhedslisten valgte på sit Årsmøde at ...
# 22770  Til marts samles unge socialister, klimaaktivi...
#
#                                               mentions
# 7                                                   []
# 16                                  ['DenGroenneStud']
# 18                                                  []
# 46                  ['informeren', 'dkgreen', 'dkpol']
# 50     ['klimamarchen', 'alternativet_', 'Naturmodet']
# ...                                                ...
# 22758                                               []
# 22763                                   ['PSkipperEL']
# 22765                                               []
# 22766                                     ['rgungdom']
# 22770                                               []
#
# [1532 rows x 4 columns]

# %%
#no. of parties retweeting about climate
print(len(klimamention.screen_name.unique()))

#no. of actors being retweeted about climate
print(len(klimamention.mentions.unique()))
# Out:
# 17
# 369

# %%
m_nx_agg = klimamention.groupby(["screen_name", "mentions"]).size().reset_index(name='simple_count')
#adding a count where we weigh the retweets of the same actor
m_nx_agg["count"] = m_nx_agg["simple_count"]**0.6
#what does it look like?
print(m_nx_agg.head(40))
print(m_nx_agg.shape)
# Out:
#         screen_name                                           mentions  \
# 0   AlternativeUnge        ['ActionAidDK', 'noedhjaelp', 'Greenpeace']
# 1   AlternativeUnge                  ['AlternativeUnge', 'tvmidtvest']
# 2   AlternativeUnge                                   ['Alternativet']
# 3   AlternativeUnge                                    ['CPHAirports']
# 4   AlternativeUnge                 ['ChristianPoll', 'alternativet_']
# 5   AlternativeUnge                      ['DanJoergensen', 'Spolitik']
# 6   AlternativeUnge                                  ['DanJoergensen']
# 7   AlternativeUnge                                    ['DanskDf1995']
# 8   AlternativeUnge                                      ['EU_Spring']
# 9   AlternativeUnge                  ['Enhedslisten', 'alternativet_']
# 10  AlternativeUnge          ['Enhedslisten', 'radikale', 'SFpolitik']
# 11  AlternativeUnge                                  ['GretaThunberg']
# 12  AlternativeUnge                                     ['HenrikGudm']
# 13  AlternativeUnge                          ['IdaAuken', 'politiken']
# 14  AlternativeUnge          ['KJungdal', 'DanJoergensen', 'Spolitik']
# 15  AlternativeUnge                ['Kristianthdahl', 'alternativet_']
# 16  AlternativeUnge  ['Kristianthdahl', 'dkpol', 'politikdr', 'saae...
# 17  AlternativeUnge                                 ['Kristianthdahl']
# 18  AlternativeUnge                                ['LiberalAlliance']
# 19  AlternativeUnge                                  ['MikeBloomberg']
# 20  AlternativeUnge                                        ['NWammen']
# 21  AlternativeUnge                                ['Pia_Kjaersgaard']
# 22  AlternativeUnge                                     ['TScavenius']
# 23  AlternativeUnge  ['alternativet_', 'AlternativeUnge', 'KbhAlter...
# 24  AlternativeUnge  ['alternativet_', 'alternativet_', 'Enhedslist...
# 25  AlternativeUnge  ['alternativet_', 'rasmusnordqvist', 'politiken']
# 26  AlternativeUnge  ['alternativet_', 'rasmusnordqvist', 'tv2newsdk']
# 27  AlternativeUnge   ['alternativet_', 'uffeelbaek', 'ChristianPoll']
# 28  AlternativeUnge                    ['alternativet_', 'uffeelbaek']
# 29  AlternativeUnge                                  ['alternativet_']
# 30  AlternativeUnge                                    ['dr2deadline']
# 31  AlternativeUnge                       ['g_mogensen', 'uffeelbaek']
# 32  AlternativeUnge                   ['helenehagel', 'alternativet_']
# 33  AlternativeUnge                                ['iLoveGlobalGoal']
# 34  AlternativeUnge                                     ['informeren']
# 35  AlternativeUnge                  ['jrgensteenniels', 'informeren']
# 36  AlternativeUnge  ['jyllandsposten', 'AlternativeUnge', 'Louisel...
# 37  AlternativeUnge                                 ['jyllandsposten']
# 38  AlternativeUnge                                    ['klimaraadet']
# 39  AlternativeUnge                   ['larsloekke', 'larsclilleholt']
#
#     simple_count     count
# 0              1  1.000000
# 1              1  1.000000
# 2              1  1.000000
# 3              1  1.000000
# 4              1  1.000000
# 5              1  1.000000
# 6              2  1.515717
# 7              1  1.000000
# 8              2  1.515717
# 9              2  1.515717
# 10             1  1.000000
# 11             3  1.933182
# 12             1  1.000000
# 13             1  1.000000
# 14             1  1.000000
# 15             1  1.000000
# 16             1  1.000000
# 17             1  1.000000
# 18             1  1.000000
# 19             1  1.000000
# 20             1  1.000000
# 21             2  1.515717
# 22             1  1.000000
# 23             1  1.000000
# 24             1  1.000000
# 25             1  1.000000
# 26             1  1.000000
# 27             1  1.000000
# 28             1  1.000000
# 29             9  3.737193
# 30             2  1.515717
# 31             1  1.000000
# 32             1  1.000000
# 33             1  1.000000
# 34             1  1.000000
# 35             1  1.000000
# 36             1  1.000000
# 37             1  1.000000
# 38             1  1.000000
# 39             1  1.000000
# (479, 4)

# %%
#creating our edge_list of sender and reciever and adding an edge attribute
Gm = nx.from_pandas_edgelist(m_nx_agg,'screen_name','mentions',
                            edge_attr="count",
                            create_using = nx.DiGraph())

# %%
for a in m_nx_agg.screen_name.unique():
    Gm.add_node(a, typ='party')

# %%
# Print the number of nodes and edges
print('Nodes in mention network:', len(Gm.nodes()))
print('Edges in mention network:', len(Gm.edges()))
# Out:
# Nodes in mention network: 386
# Edges in mention network: 479

# %%
nx.write_gexf(Gm, 'mentions_climate.gexf')

# %%
from pyvis import network as net

pyvis_m_graph = net.Network(notebook = True, height = '700px', width = '700px', bgcolor = '#f6f2e9')

# %%
pyvis_m_graph.force_atlas_2based()
pyvis_m_graph.from_nx(Gm)

pyvis_m_graph.show('climate_mentions_nw.html')
# Out:
#         <iframe
#             width="700px"
#             height="700px"
#             src="climate_mentions_nw.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Create size list
sizes = [x[1] for x in Gm.degree()]

# Draw the network
nx.draw_networkx(Gm, 
    with_labels = False, 
    node_size = sizes,
    width = 0.1, alpha = 0.7,
    arrowsize = 2, linewidths = 0)

# Turn axis off and show
plt.axis('off'); plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     395         try:
# --> 396             random_state_arg = args[random_state_index]
#     397         except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-68-203d27381576> in <module>
#       3
#       4 # Draw the network
# ----> 5 nx.draw_networkx(Gm,
#       6     with_labels = False,
#       7     node_size = sizes,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     331
#     332     if pos is None:
# --> 333         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     334
#     335     draw_networkx_nodes(G, pos, **node_kwds)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     398             raise nx.NetworkXError("random_state_index must be an integer") from e
#     399         except IndexError as e:
# --> 400             raise nx.NetworkXError("random_state_index is incorrect") from e
#     401
#     402         # Create a numpy.random.RandomState instance
#
# NetworkXError: random_state_index is incorrect
